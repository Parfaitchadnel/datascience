# %%
import pandas as pd
data = {'Nom': ['Parmienne', 'Danel',"Chadnel"], 
        'Âge': [3, 1,0],
        'Sexe': ["F",'F',"M"]}
df = pd.DataFrame(data)
#Afficher le tableau
#df
#transformer le tableau en fichier .csv
#df.to_csv('liste_etudiant.csv', index=False)
#Afficher seulement les nom
#df['Nom']
#df.iloc[0]
#statistique
#df.describe()
#df.sort_values(by='Âge', ascending=False)
import matplotlib.pyplot as plt

df.plot(x='Nom', y='Âge', kind='bar', color='blue')
plt.title("Âge des étudiants")
plt.xlabel("Nom")
plt.ylabel("Âge")
plt.show()
